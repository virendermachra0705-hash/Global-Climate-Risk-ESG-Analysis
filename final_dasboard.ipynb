# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv('cleaned_master.csv')
data.head(5)
# Out:
#   Country Name  Access to electricity (% of population)  \
# 0    singapore                                      1.0
# 1    singapore                                      1.0
# 2    singapore                                      1.0
# 3      denmark                                      1.0
# 4      finland                                      1.0
#
#    Control of Corruption: Estimate  Government Effectiveness: Estimate  \
# 0                         0.922711                            1.000000
# 1                         0.922711                            1.000000
# 2                         0.922711                            1.000000
# 3                         1.000000                            0.935027
# 4                         0.964438                            0.875388
#
#    Regulatory Quality: Estimate  Rule of Law: Estimate  ESG_Proxy  E_Score  \
# 0                      1.000000               0.948823   0.974307      1.0
# ...

# %%
data.drop(['ESG_Final_norm','GDP_2020_norm','Temperature_norm','SDI_2019_norm'], axis=1,inplace=True)

# %%
data.columns.tolist()
# Out:
# ['Country Name',
#  'Access to electricity (% of population)',
#  'Control of Corruption: Estimate',
#  'Government Effectiveness: Estimate',
#  'Regulatory Quality: Estimate',
#  'Rule of Law: Estimate',
#  'ESG_Proxy',
#  'E_Score',
#  'S_Score',
#  'G_Score',
#  'ESG_Final',
#  'Temperature',
#  'GDP_2020',
#  'POP_2020',
#  'SDI_2019',
#  'Economic_Index',
#  'Sustainability_Index',
#  'Climate_Risk_Index']

# %%
data.head(5)
# Out:
#   Country Name  Access to electricity (% of population)  \
# 0    singapore                                      1.0
# 1    singapore                                      1.0
# 2    singapore                                      1.0
# 3      denmark                                      1.0
# 4      finland                                      1.0
#
#    Control of Corruption: Estimate  Government Effectiveness: Estimate  \
# 0                         0.922711                            1.000000
# 1                         0.922711                            1.000000
# 2                         0.922711                            1.000000
# 3                         1.000000                            0.935027
# 4                         0.964438                            0.875388
#
#    Regulatory Quality: Estimate  Rule of Law: Estimate  ESG_Proxy  E_Score  \
# 0                      1.000000               0.948823   0.974307      1.0
# ...

# %%
for col in ['E_Score', 'S_Score', 'G_Score', 'ESG_Final']:
    data[col] = data[col] * 100

# %%
data.head()
# Out:
#   Country Name  Access to electricity (% of population)  \
# 0    singapore                                      1.0
# 1    singapore                                      1.0
# 2    singapore                                      1.0
# 3      denmark                                      1.0
# 4      finland                                      1.0
#
#    Control of Corruption: Estimate  Government Effectiveness: Estimate  \
# 0                         0.922711                            1.000000
# 1                         0.922711                            1.000000
# 2                         0.922711                            1.000000
# 3                         1.000000                            0.935027
# 4                         0.964438                            0.875388
#
#    Regulatory Quality: Estimate  Rule of Law: Estimate  ESG_Proxy  E_Score  \
# 0                      1.000000               0.948823   0.974307    100.0
# ...

# %%
data.drop(columns=['ESG_Proxy'],inplace=True)

# %%
data.head(5)
# Out:
#   Country Name  Access to electricity (% of population)  \
# 0    singapore                                      1.0
# 1    singapore                                      1.0
# 2    singapore                                      1.0
# 3      denmark                                      1.0
# 4      finland                                      1.0
#
#    Control of Corruption: Estimate  Government Effectiveness: Estimate  \
# 0                         0.922711                            1.000000
# 1                         0.922711                            1.000000
# 2                         0.922711                            1.000000
# 3                         1.000000                            0.935027
# 4                         0.964438                            0.875388
#
#    Regulatory Quality: Estimate  Rule of Law: Estimate  E_Score  S_Score  \
# 0                      1.000000               0.948823    100.0    100.0
# ...

# %%
data['Economic_Index'] = data['Economic_Index'] * 100
data['Sustainability_Index'] = data['Sustainability_Index'] * 100
data['Climate_Risk_Index'] = data['Climate_Risk_Index'] * 100

# %%
data.head()
# Out:
#   Country Name  Access to electricity (% of population)  \
# 0    singapore                                      1.0
# 1    singapore                                      1.0
# 2    singapore                                      1.0
# 3      denmark                                      1.0
# 4      finland                                      1.0
#
#    Control of Corruption: Estimate  Government Effectiveness: Estimate  \
# 0                         0.922711                            1.000000
# 1                         0.922711                            1.000000
# 2                         0.922711                            1.000000
# 3                         1.000000                            0.935027
# 4                         0.964438                            0.875388
#
#    Regulatory Quality: Estimate  Rule of Law: Estimate  E_Score  S_Score  \
# 0                      1.000000               0.948823    100.0    100.0
# ...

# %%
data.to_csv("final_dasboard.csv",index=False)
